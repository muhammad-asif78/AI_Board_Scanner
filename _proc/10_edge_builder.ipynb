# %% [raw]
# ---
# output-file: edge_builder.html
# title: Edge Builder
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(create_edges_json)
# Out:
# ---
#
# [source](https://github.com/muhammad-asif78/nbdev_testing_simon2/blob/main/pipeline/json_builders/edge_builder.py#L11){target="_blank" style="float:right; font-size:smaller"}
#
# ### create_edges_json
#
# >      create_edges_json (arrow_connections, diagram_nodes, all_dets_with_color,
# >                         arrowhead_radius=50)
