# %% [raw]
# ---
# output-file: download_models.html
# title: Download Models
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(download_paddleocr_models)
# Out:
# ---
#
# [source](https://github.com/muhammad-asif78/nbdev_testing_simon2/blob/main/pipeline/download_models.py#L7){target="_blank" style="float:right; font-size:smaller"}
#
# ### download_paddleocr_models
#
# >      download_paddleocr_models (lang:str='en')
