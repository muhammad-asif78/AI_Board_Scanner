# %% [raw]
# ---
# output-file: routers_spatial.html
# title: Spatial Router
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(spatial_map)
# Out:
# ---
#
# [source](https://github.com/muhammad-asif78/nbdev_testing_simon2/blob/main/pipeline/routers/spatial.py#L147){target="_blank" style="float:right; font-size:smaller"}
#
# ### spatial_map
#
# >      spatial_map
# >                   (file:fastapi.datastructures.UploadFile=File(PydanticUndefin
# >                   ed))
#
# *Convert a diagram image to JSON spatial representation.*

# %%
#| echo: false
#| output: asis
show_doc(health_check)
# Out:
# ---
#
# [source](https://github.com/muhammad-asif78/nbdev_testing_simon2/blob/main/pipeline/routers/spatial.py#L137){target="_blank" style="float:right; font-size:smaller"}
#
# ### health_check
#
# >      health_check ()
#
# *Simple health check endpoint.*

# %%
#| echo: false
#| output: asis
show_doc(readiness_check)
# Out:
# ---
#
# [source](https://github.com/muhammad-asif78/nbdev_testing_simon2/blob/main/pipeline/routers/spatial.py#L44){target="_blank" style="float:right; font-size:smaller"}
#
# ### readiness_check
#
# >      readiness_check ()
#
# *Check if the service is ready to handle requests.*

# %%
#| echo: false
#| output: asis
show_doc(SpatialMapResponse)
# Out:
# ---
#
# [source](https://github.com/muhammad-asif78/nbdev_testing_simon2/blob/main/pipeline/models.py#L353){target="_blank" style="float:right; font-size:smaller"}
#
# ### SpatialMapResponse
#
# >      SpatialMapResponse (success:bool=True, status:str='ok', code:int=200,
# >                          data:Dict[str,Any])
#
# *!!! abstract "Usage Documentation"
#     [Models](../concepts/models.md)
#
# A base class for creating Pydantic models.
#
# Attributes:
#     __class_vars__: The names of the class variables defined on the model.
#     __private_attributes__: Metadata about the private attributes of the model.
#     __signature__: The synthesized `__init__` [`Signature`][inspect.Signature] of the model.
#
#     __pydantic_complete__: Whether model building is completed, or if there are still undefined fields.
#     __pydantic_core_schema__: The core schema of the model.
#     __pydantic_custom_init__: Whether the model has a custom `__init__` function.
# ...

# %%
#| echo: false
#| output: asis
show_doc(ReadinessResponse)
# Out:
# ---
#
# [source](https://github.com/muhammad-asif78/nbdev_testing_simon2/blob/main/pipeline/models.py#L84){target="_blank" style="float:right; font-size:smaller"}
#
# ### ReadinessResponse
#
# >      ReadinessResponse (success:bool=True, status:str='ready', code:int=200,
# >                         message:str='Service is ready to handle requests')
#
# *!!! abstract "Usage Documentation"
#     [Models](../concepts/models.md)
#
# A base class for creating Pydantic models.
#
# Attributes:
#     __class_vars__: The names of the class variables defined on the model.
#     __private_attributes__: Metadata about the private attributes of the model.
#     __signature__: The synthesized `__init__` [`Signature`][inspect.Signature] of the model.
#
#     __pydantic_complete__: Whether model building is completed, or if there are still undefined fields.
#     __pydantic_core_schema__: The core schema of the model.
# ...

# %%
#| echo: false
#| output: asis
show_doc(ErrorDetail)
# Out:
# ---
#
# [source](https://github.com/muhammad-asif78/nbdev_testing_simon2/blob/main/pipeline/models.py#L31){target="_blank" style="float:right; font-size:smaller"}
#
# ### ErrorDetail
#
# >      ErrorDetail (success:bool=False, status:str='error', code:int,
# >                   message:str)
#
# *!!! abstract "Usage Documentation"
#     [Models](../concepts/models.md)
#
# A base class for creating Pydantic models.
#
# Attributes:
#     __class_vars__: The names of the class variables defined on the model.
#     __private_attributes__: Metadata about the private attributes of the model.
#     __signature__: The synthesized `__init__` [`Signature`][inspect.Signature] of the model.
#
#     __pydantic_complete__: Whether model building is completed, or if there are still undefined fields.
#     __pydantic_core_schema__: The core schema of the model.
#     __pydantic_custom_init__: Whether the model has a custom `__init__` function.
# ...
