# %% [raw]
# ---
# output-file: arrow_detector.html
# title: Arrow Detector
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(find_arrow_endpoints)
# Out:
# ---
#
# [source](https://github.com/muhammad-asif78/nbdev_testing_simon2/blob/main/pipeline/arrow_processing/arrow_detector.py#L35){target="_blank" style="float:right; font-size:smaller"}
#
# ### find_arrow_endpoints
#
# >      find_arrow_endpoints (image_bgr, detections, ocr_results)

# %%
#| echo: false
#| output: asis
show_doc(convert_to_binary_mask)
# Out:
# ---
#
# [source](https://github.com/muhammad-asif78/nbdev_testing_simon2/blob/main/pipeline/arrow_processing/arrow_detector.py#L21){target="_blank" style="float:right; font-size:smaller"}
#
# ### convert_to_binary_mask
#
# >      convert_to_binary_mask (cropped_img)

# %%
#| echo: false
#| output: asis
show_doc(crop_image_region)
# Out:
# ---
#
# [source](https://github.com/muhammad-asif78/nbdev_testing_simon2/blob/main/pipeline/arrow_processing/arrow_detector.py#L15){target="_blank" style="float:right; font-size:smaller"}
#
# ### crop_image_region
#
# >      crop_image_region (image, top_left, bottom_right)
