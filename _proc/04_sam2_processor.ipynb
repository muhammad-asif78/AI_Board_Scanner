# %% [raw]
# ---
# output-file: sam2_processor.html
# title: SAM2 Processor
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(predict_angles_with_masks)
# Out:
# ---
#
# [source](https://github.com/muhammad-asif78/nbdev_testing_simon2/blob/main/pipeline/angle_detection/sam2_processor.py#L163){target="_blank" style="float:right; font-size:smaller"}
#
# ### predict_angles_with_masks
#
# >      predict_angles_with_masks (image_bgr, detections)
