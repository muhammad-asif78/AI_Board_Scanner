# %% [raw]
# ---
# output-file: color_extractor.html
# title: Color Extractor
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(attach_colors)
# Out:
# ---
#
# [source](https://github.com/muhammad-asif78/nbdev_testing_simon2/blob/main/pipeline/shape_processing/color_extractor.py#L206){target="_blank" style="float:right; font-size:smaller"}
#
# ### attach_colors
#
# >      attach_colors (image_bgr, detections)

# %%
#| echo: false
#| output: asis
show_doc(find_dominant_color)
# Out:
# ---
#
# [source](https://github.com/muhammad-asif78/nbdev_testing_simon2/blob/main/pipeline/shape_processing/color_extractor.py#L169){target="_blank" style="float:right; font-size:smaller"}
#
# ### find_dominant_color
#
# >      find_dominant_color (image, shape_type='rectangle', bbox=None, k=4,
# >                           least_prominent=False, bg_rgb=(255, 255, 255),
# >                           bg_thresh=24)

# %%
#| echo: false
#| output: asis
show_doc(extract_shape_mask)
# Out:
# ---
#
# [source](https://github.com/muhammad-asif78/nbdev_testing_simon2/blob/main/pipeline/shape_processing/color_extractor.py#L95){target="_blank" style="float:right; font-size:smaller"}
#
# ### extract_shape_mask
#
# >      extract_shape_mask (H, W, shape_type, bbox, vector_data=None)

# %%
#| echo: false
#| output: asis
show_doc(get_corner_background_color)
# Out:
# ---
#
# [source](https://github.com/muhammad-asif78/nbdev_testing_simon2/blob/main/pipeline/shape_processing/color_extractor.py#L80){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_corner_background_color
#
# >      get_corner_background_color (image)

# %%
#| echo: false
#| output: asis
show_doc(rgb_to_hex)
# Out:
# ---
#
# [source](https://github.com/muhammad-asif78/nbdev_testing_simon2/blob/main/pipeline/shape_processing/color_extractor.py#L69){target="_blank" style="float:right; font-size:smaller"}
#
# ### rgb_to_hex
#
# >      rgb_to_hex (rgb_tuple)

# %%
#| echo: false
#| output: asis
show_doc(find_dominant_color_masked)
# Out:
# ---
#
# [source](https://github.com/muhammad-asif78/nbdev_testing_simon2/blob/main/pipeline/shape_processing/color_extractor.py#L12){target="_blank" style="float:right; font-size:smaller"}
#
# ### find_dominant_color_masked
#
# >      find_dominant_color_masked (image_crop, mask=None, k=3)
