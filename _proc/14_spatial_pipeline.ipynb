# %% [raw]
# ---
# output-file: spatial_pipeline.html
# title: Spatial Pipeline
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(run_spatial_mapping)
# Out:
# ---
#
# [source](https://github.com/muhammad-asif78/nbdev_testing_simon2/blob/main/pipeline/spatial_pipeline.py#L72){target="_blank" style="float:right; font-size:smaller"}
#
# ### run_spatial_mapping
#
# >      run_spatial_mapping (file_path:str)
