# %% [raw]
# ---
# output-file: node_builder.html
# title: Node Builder
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(attach_angles_to_nodes)
# Out:
# ---
#
# [source](https://github.com/muhammad-asif78/nbdev_testing_simon2/blob/main/pipeline/json_builders/node_builder.py#L66){target="_blank" style="float:right; font-size:smaller"}
#
# ### attach_angles_to_nodes
#
# >      attach_angles_to_nodes (diagram_nodes, detections, angle_map)

# %%
#| echo: false
#| output: asis
show_doc(find_node_by_det)
# Out:
# ---
#
# [source](https://github.com/muhammad-asif78/nbdev_testing_simon2/blob/main/pipeline/json_builders/node_builder.py#L48){target="_blank" style="float:right; font-size:smaller"}
#
# ### find_node_by_det
#
# >      find_node_by_det (diagram_nodes, det, tol=8)

# %%
#| echo: false
#| output: asis
show_doc(create_nodes_json)
# Out:
# ---
#
# [source](https://github.com/muhammad-asif78/nbdev_testing_simon2/blob/main/pipeline/json_builders/node_builder.py#L12){target="_blank" style="float:right; font-size:smaller"}
#
# ### create_nodes_json
#
# >      create_nodes_json (shape_detections_with_color)
